# %%
import opendatasets as od
dataset_url = 'https://www.kaggle.com/gpreda/covid-world-vaccination-progress'
od.download(dataset_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: amassinnacerddine
# Your Kaggle Key: ········
# 100%|██████████| 233k/233k [00:00<00:00, 9.71MB/s]
# Downloading covid-world-vaccination-progress.zip to ./covid-world-vaccination-progress

# %%
data_dir = './covid-world-vaccination-progress'

# %%
import os
os.listdir(data_dir)
# Out:
# ['country_vaccinations.csv']

# %%
import pandas as pd
vaccine_data = pd.read_csv(data_dir + '/country_vaccinations.csv')

# %%
vaccine_data
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 10752     Zimbabwe      ZWE  2021-04-03            132915.0
# 10753     Zimbabwe      ZWE  2021-04-04            138900.0
# 10754     Zimbabwe      ZWE  2021-04-05            145510.0
# 10755     Zimbabwe      ZWE  2021-04-06            162633.0
# 10756     Zimbabwe      ZWE  2021-04-07            179417.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# 2                    NaN                      NaN                     NaN
# 3                    NaN                      NaN                     NaN
# 4                    NaN                      NaN                     NaN
# ...                  ...                      ...                     ...
# 10752           111588.0                  21327.0                  8162.0
# 10753           117297.0                  21603.0                  5985.0
# 10754           123454.0                  22056.0                  6610.0
# 10755           139133.0                  23500.0                 17123.0
# 10756           153238.0                  26179.0                 16784.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 0                     NaN                            0.00
# 1                  1367.0                             NaN
# 2                  1367.0                             NaN
# 3                  1367.0                             NaN
# 4                  1367.0                             NaN
# ...                   ...                             ...
# 10752              8498.0                            0.89
# 10753              8537.0                            0.93
# 10754              9129.0                            0.98
# 10755             10967.0                            1.09
# 10756             12505.0                            1.21
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                               0.00                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
# ...                              ...                                  ...
# 10752                           0.75                                 0.14
# 10753                           0.79                                 0.15
# 10754                           0.83                                 0.15
# 10755                           0.94                                 0.16
# 10756                           1.03                                 0.18
#
#        daily_vaccinations_per_million            vaccines  \
# 0                                 NaN  Oxford/AstraZeneca
# 1                                35.0  Oxford/AstraZeneca
# 2                                35.0  Oxford/AstraZeneca
# 3                                35.0  Oxford/AstraZeneca
# 4                                35.0  Oxford/AstraZeneca
# ...                               ...                 ...
# 10752                           572.0   Sinopharm/Beijing
# 10753                           574.0   Sinopharm/Beijing
# 10754                           614.0   Sinopharm/Beijing
# 10755                           738.0   Sinopharm/Beijing
# 10756                           841.0   Sinopharm/Beijing
#
#                      source_name  \
# 0      Government of Afghanistan
# 1      Government of Afghanistan
# 2      Government of Afghanistan
# 3      Government of Afghanistan
# 4      Government of Afghanistan
# ...                          ...
# 10752         Ministry of Health
# 10753         Ministry of Health
# 10754         Ministry of Health
# 10755         Ministry of Health
# 10756         Ministry of Health
#
#                                           source_website
# 0      http://www.xinhuanet.com/english/asiapacific/2...
# 1      http://www.xinhuanet.com/english/asiapacific/2...
# 2      http://www.xinhuanet.com/english/asiapacific/2...
# 3      http://www.xinhuanet.com/english/asiapacific/2...
# 4      http://www.xinhuanet.com/english/asiapacific/2...
# ...                                                  ...
# 10752  https://twitter.com/MoHCCZim/status/1379872908...
# 10753  https://twitter.com/MoHCCZim/status/1379872908...
# 10754  https://twitter.com/MoHCCZim/status/1379872908...
# 10755  https://twitter.com/MoHCCZim/status/1379872908...
# 10756  https://twitter.com/MoHCCZim/status/1379872908...
#
# [10757 rows x 15 columns]

# %%
vaccine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10757 entries, 0 to 10756
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              10757 non-null  object
#  1   iso_code                             10757 non-null  object
#  2   date                                 10757 non-null  object
#  3   total_vaccinations                   6472 non-null   float64
#  4   people_vaccinated                    5834 non-null   float64
#  5   people_fully_vaccinated              4154 non-null   float64
#  6   daily_vaccinations_raw               5417 non-null   float64
#  7   daily_vaccinations                   10563 non-null  float64
#  8   total_vaccinations_per_hundred       6472 non-null   float64
#  9   people_vaccinated_per_hundred        5834 non-null   float64
#  10  people_fully_vaccinated_per_hundred  4154 non-null   float64
#  11  daily_vaccinations_per_million       10563 non-null  float64
#  12  vaccines                             10757 non-null  object
#  13  source_name                          10757 non-null  object
#  14  source_website                       10757 non-null  object
# dtypes: float64(9), object(6)
# memory usage: 1.2+ MB

# %%
vaccine_data.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        6.472000e+03       5.834000e+03             4.154000e+03
# mean         3.565692e+06       2.550182e+06             1.154847e+06
# std          1.367473e+07       8.863178e+06             4.770130e+06
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          5.094500e+04       4.836000e+04             2.168900e+04
# 50%          3.428795e+05       2.910530e+05             1.429075e+05
# 75%          1.593779e+06       1.176837e+06             5.689088e+05
# max          1.788378e+08       1.144360e+08             6.820246e+07
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            5.417000e+03        1.056300e+04
# mean             1.178874e+05        6.971190e+04
# std              4.364602e+05        2.945452e+05
# min             -2.928600e+04        0.000000e+00
# 25%              3.161000e+03        9.860000e+02
# 50%              1.517700e+04        5.949000e+03
# 75%              5.946300e+04        2.779400e+04
# max              7.185000e+06        5.190143e+06
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                     6472.000000                    5834.000000
# mean                        12.127713                       9.154373
# std                         20.099445                      13.529680
# min                          0.000000                       0.000000
# 25%                          0.950000                       0.910000
# 50%                          4.660000                       3.735000
# 75%                         14.375000                      11.057500
# max                        185.040000                      97.640000
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# count                          4154.000000                    10563.000000
# mean                              4.361981                     2835.101486
# std                               8.791505                     5022.729887
# min                               0.000000                        0.000000
# 25%                               0.470000                      339.000000
# 50%                               1.680000                     1395.000000
# 75%                               4.310000                     3499.000000
# max                              87.400000                   118759.000000

# %%
Total_vaccinations=vaccine_data.groupby('country')['daily_vaccinations'].cumsum()
Total_vaccinations
# Out:
# 0             NaN
# 1          1367.0
# 2          2734.0
# 3          4101.0
# 4          5468.0
#            ...
# 10752    101469.0
# 10753    110006.0
# 10754    119135.0
# 10755    130102.0
# 10756    142607.0
# Name: daily_vaccinations, Length: 10757, dtype: float64

# %%
vaccine_data.insert(5,'Total_vaccinations',Total_vaccinations)

# %%
vaccine_data.head(107)
# Out:
#          country iso_code        date  total_vaccinations  people_vaccinated  \
# 0    Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1    Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2    Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3    Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4    Afghanistan      AFG  2021-02-26                 NaN                NaN
# ..           ...      ...         ...                 ...                ...
# 102      Albania      ALB  2021-03-08                 NaN                NaN
# 103      Albania      ALB  2021-03-09                 NaN                NaN
# 104      Albania      ALB  2021-03-10             21613.0                NaN
# 105      Albania      ALB  2021-03-11                 NaN                NaN
# 106      Albania      ALB  2021-03-12             23635.0                NaN
#
#      Total_vaccinations  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                   NaN                      NaN                     NaN
# 1                1367.0                      NaN                     NaN
# 2                2734.0                      NaN                     NaN
# 3                4101.0                      NaN                     NaN
# 4                5468.0                      NaN                     NaN
# ..                  ...                      ...                     ...
# 102             17660.0                      NaN                     NaN
# 103             18480.0                      NaN                     NaN
# 104             19311.0                      NaN                     NaN
# 105             20168.0                      NaN                     NaN
# 106             21051.0                      NaN                     NaN
#
#      daily_vaccinations  total_vaccinations_per_hundred  \
# 0                   NaN                            0.00
# 1                1367.0                             NaN
# 2                1367.0                             NaN
# 3                1367.0                             NaN
# 4                1367.0                             NaN
# ..                  ...                             ...
# 102               808.0                             NaN
# 103               820.0                             NaN
# 104               831.0                            0.75
# 105               857.0                             NaN
# 106               883.0                            0.82
#
#      people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                              0.0                                  NaN
# 1                              NaN                                  NaN
# 2                              NaN                                  NaN
# 3                              NaN                                  NaN
# 4                              NaN                                  NaN
# ..                             ...                                  ...
# 102                            NaN                                  NaN
# 103                            NaN                                  NaN
# 104                            NaN                                  NaN
# 105                            NaN                                  NaN
# 106                            NaN                                  NaN
#
#      daily_vaccinations_per_million                  vaccines  \
# 0                               NaN        Oxford/AstraZeneca
# 1                              35.0        Oxford/AstraZeneca
# 2                              35.0        Oxford/AstraZeneca
# 3                              35.0        Oxford/AstraZeneca
# 4                              35.0        Oxford/AstraZeneca
# ..                              ...                       ...
# 102                           281.0  Pfizer/BioNTech, Sinovac
# 103                           285.0  Pfizer/BioNTech, Sinovac
# 104                           289.0  Pfizer/BioNTech, Sinovac
# 105                           298.0  Pfizer/BioNTech, Sinovac
# 106                           307.0  Pfizer/BioNTech, Sinovac
#
#                    source_name  \
# 0    Government of Afghanistan
# 1    Government of Afghanistan
# 2    Government of Afghanistan
# 3    Government of Afghanistan
# 4    Government of Afghanistan
# ..                         ...
# 102         Ministry of Health
# 103         Ministry of Health
# 104         Ministry of Health
# 105         Ministry of Health
# 106         Ministry of Health
#
#                                         source_website
# 0    http://www.xinhuanet.com/english/asiapacific/2...
# 1    http://www.xinhuanet.com/english/asiapacific/2...
# 2    http://www.xinhuanet.com/english/asiapacific/2...
# 3    http://www.xinhuanet.com/english/asiapacific/2...
# 4    http://www.xinhuanet.com/english/asiapacific/2...
# ..                                                 ...
# 102  https://twitter.com/gmanastirliu/status/138023...
# 103  https://twitter.com/gmanastirliu/status/138023...
# 104  https://twitter.com/gmanastirliu/status/138023...
# 105  https://twitter.com/gmanastirliu/status/138023...
# 106  https://twitter.com/gmanastirliu/status/138023...
#
# [107 rows x 16 columns]

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
plt.figure(figsize=(12,6))
plt.plot(vaccine_data[vaccine_data['country']=='India'].date,vaccine_data[vaccine_data['country']=='India'].daily_vaccinations);
plt.plot(vaccine_data[vaccine_data['country']=='France'].date,vaccine_data[vaccine_data['country']=='France'].daily_vaccinations);
plt.plot(vaccine_data[vaccine_data['country']=='United States'].date,vaccine_data[vaccine_data['country']=='United States'].daily_vaccinations);
plt.plot(vaccine_data[vaccine_data['country']=='Germany'].date,vaccine_data[vaccine_data['country']=='Germany'].daily_vaccinations);
plt.plot(vaccine_data[vaccine_data['country']=='China'].date,vaccine_data[vaccine_data['country']=='China'].daily_vaccinations);
plt.plot(vaccine_data[vaccine_data['country']=='United Kingdom'].date,vaccine_data[vaccine_data['country']=='United Kingdom'].daily_vaccinations);

plt.xlabel("Date")
plt.ylabel("Daily vaccinations in 10 Millions")

plt.title("Major countries in vaccination process by Daily vaccination");
plt.legend(['India','France','United States','Germany','China','United Kingdom']);
#Well organised graph country wise

# %%
import pandas as pd
covid_data = pd.read_csv(data_dir + '/owid-covid-data.csv')

# %%
france_death=covid_data[covid_data['location']=='France'].agg({'new_deaths':'sum'})
# Out:
# new_deaths    98909.0
# dtype: float64

# %%
total_death=covid_data.groupby('location').agg({'new_deaths':'sum'})
total_death
# Out:
# pandas.core.frame.DataFrame

# %%
total_death.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 215 entries, Afghanistan to Zimbabwe
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   new_deaths  215 non-null    float64
# dtypes: float64(1)
# memory usage: 3.4+ KB
