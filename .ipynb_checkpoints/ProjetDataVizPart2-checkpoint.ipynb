# %%
import pycountry
len(pycountry.countries)
iso_country=list(pycountry.countries)
#print(iso_country[0].alpha_3)

# %%
data_dir = './datasets'
import os
os.listdir(data_dir)
# Out:
# ['.DS_Store',
#  'corona-virus-report',
#  'owid-covid-data.csv',
#  'covid-world-vaccination-progress',
#  'country_wise_latest.csv']

# %%
import pandas as pd
covid_data = pd.read_csv(data_dir + '/owid-covid-data.csv')
covid_data
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 80981      ZWE    Africa     Zimbabwe  2021-04-07      36984.0       18.0
# 80982      ZWE    Africa     Zimbabwe  2021-04-08      37052.0       68.0
# 80983      ZWE    Africa     Zimbabwe  2021-04-09      37147.0       95.0
# 80984      ZWE    Africa     Zimbabwe  2021-04-10      37273.0      126.0
# 80985      ZWE    Africa     Zimbabwe  2021-04-11      37288.0       15.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
total_death=covid_data.groupby('iso_code').agg({'new_deaths':'sum',
                                                'location':'first',
                                                'iso_code':'first',
                                                'location':'first'})
#total_death['new_deaths'][0]
total_death
# Out:
#           new_deaths      location iso_code
# iso_code
# AFG           2521.0   Afghanistan      AFG
# AGO            553.0        Angola      AGO
# AIA              0.0      Anguilla      AIA
# ALB           2317.0       Albania      ALB
# AND            120.0       Andorra      AND
# ...              ...           ...      ...
# WSM              0.0         Samoa      WSM
# YEM           1049.0         Yemen      YEM
# ZAF          53322.0  South Africa      ZAF
# ZMB           1226.0        Zambia      ZMB
# ZWE           1538.0      Zimbabwe      ZWE
#
# [215 rows x 3 columns]

# %%
total_cases=covid_data.groupby('iso_code').agg({'new_cases':'sum',
                                               'location':'first',
                                               'iso_code':'first',
                                               'location':'first'})


total_cases
# Out:
#           new_cases      location iso_code
# iso_code
# AFG         57160.0   Afghanistan      AFG
# AGO         23457.0        Angola      AGO
# AIA             0.0      Anguilla      AIA
# ALB        128393.0       Albania      ALB
# AND         12545.0       Andorra      AND
# ...             ...           ...      ...
# WSM             3.0         Samoa      WSM
# YEM          5357.0         Yemen      YEM
# ZAF       1558458.0  South Africa      ZAF
# ZMB         90029.0        Zambia      ZMB
# ZWE         37288.0      Zimbabwe      ZWE
#
# [215 rows x 3 columns]

# %%
country_data_dir = './datasets'
import os
os.listdir(country_data_dir)
# Out:
# ['.DS_Store',
#  'countries.csv',
#  'corona-virus-report',
#  'owid-covid-data.csv',
#  'covid-world-vaccination-progress',
#  'country_wise_latest.csv']

# %%
import pandas as pd
country_data = pd.read_csv(country_data_dir + '/countries.csv')
country_data
# Out:
# 0                   Andorra
# 1      United Arab Emirates
# 2               Afghanistan
# 3       Antigua and Barbuda
# 4                  Anguilla
#                ...
# 240                   Yemen
# 241                 Mayotte
# 242            South Africa
# 243                  Zambia
# 244                Zimbabwe
# Name: name, Length: 245, dtype: object

# %%
l=country_data.groupby('name').agg({'latitude':'first',
                                    'longitude':'first',
                                    'name':'first'})

h=l.loc[l['name'] == 'Algeria']
h['latitude'].to_numpy()[0]
# Out:
# 28.033886

# %%
import folium
from folium.plugins import MarkerCluster


m = folium.Map(location=[46.227638, 2.213749], zoom_start=3,min_zoom=3,max_zoom=5)

marker_cluster = MarkerCluster().add_to(m)

for i in range(0,35):
    
    
    la=country_data[country_data['name']==total_cases['location'][i]]['latitude']
    
    lo=country_data[country_data['name']==total_cases['location'][i]]['longitude']
    total_cases['new_cases'][i]
    total_death['new_deaths'][i]
    
    folium.Marker(
        location=[la.to_numpy()[0], lo.to_numpy()[0]],
        
        popup =
                            "Pays: " + str(total_cases.location[i]) + '<br>' +
                            "Mort: " + str(total_death.new_deaths[i]) + '<br>' +
                            "Cas: " + str(total_cases.new_cases[i]) + '<br>'
                        ,
        icon=folium.Icon(color="red", icon="cloud"),
    ).add_to(marker_cluster)
   

"""folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)"""

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
